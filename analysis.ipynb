# %% [markdown]
# Importing Packages

# %%
import numpy as np 
import pandas as pd 
import matplotlib as plt

# %% [markdown]
# Summary Statistics

# %%
df = pd.read_csv('clean-cyber-operations-incidents.csv')
df.head()
# Out:
#                                                Title       Date  \
# 0  Targeting of dissidents and opposition politic...  1/20/2022
# 1              Targeting of Ukrainian state entities   3/7/2022
# 2       Targeting of Russian and Belarusian websites   5/4/2022
# 3  Targeting of the Belgian Federal Public Servic...  7/18/2022
# 4         Targeting of Ukrainian government agencies  8/11/2022
#
#                                     Affiliations  \
# 0  Believed to be the work of Ghana's government
# 1                                        UNC1151
# 2                              Ukrainian IT Army
# 3                                      Zirconium
# 4                                      Gamaredon
#
#                                          Description  \
# 0  The Israeli spyware firm NSO Group sold Pegasu...
# 1  The Belarusian threat actor UNC1151 targeted m...
# 2  Ukraine?? IT Army compromised Docker Engine ho...
# 3  Chinese threat actors targeted the Belgian Fed...
# ...

# %%
df.describe()
# Out:
#                                                     Title       Date  \
# count                                                 768        753
# unique                                                764        603
# top     Targeting of Afghan telecommunication firm Roshan  4/27/2022
# freq                                                    2          6
#
#          Affiliations                                        Description  \
# count             621                                                768
# unique            377                                                767
# top     Lazarus Group  Chinese threat actors targeted the Belgian Fed...
# freq               26                                                  2
#
#        Response        Victims Sponsor       Type        Category  \
# count       186            741     729        731             743
# unique      128            657      65         12              35
# ...

# %%
df[["Sponsor", "Type"]].describe()
# Out:
#        Sponsor       Type
# count      729        731
# unique      65         12
# top      China  Espionage
# freq       256        608

# %% [markdown]
# Contingency Table

# %%
data_crosstab = pd.crosstab(df['Sponsor'], 
                            df['Type'],  
                               margins = False) 
print(data_crosstab)
# Out:
# Type                      Data destruction  Defacement  Denial of service  \
# Sponsor
#  Australia                               0           0                  0
#  Bulgaria                                0           0                  0
#  Canada                                  0           0                  0
#  France                                  0           0                  0
#  Germany                                 0           0                  0
# ...                                    ...         ...                ...
# United Kingdom                           0           0                  0
# United States                            2           0                  2
# United States of America                 0           0                  1
# Uzbekistan                               0           0                  0
# Vietnam                                  0           0                  0
#
# ...
